# %%
class hotel:
    def welcome(self,obj):
        print("                         # WELCOME TO YASH KA DABHA #")
        print("                       ---------------------------------")
        Obj.getMenu().printMenu(Obj)
    
    
class menu:
    def printMenu(self,Obj):
#         flag = True
#         while flag:
            print("Select your Option:-")
            print("A.Snacks")
            print("B.Veg")
            print("C.Non-Veg")
            print("D.Dessorts")
            print("E.Exit")
            option = input("Enter the your option A/B/C/D/E:-")
            if(option=="A"):
                Obj.getMenuPrint().Snacks(Obj)
                option = int(input("Enter your Dish name:"))
                if(option==1):
                    print(Obj.getDishName().getSamosa(Obj),"      ",Obj.getPrice().getssprice(Obj),"Rs")
                    qty = int(input("Enter your quantity for Samosa:"))
                    print("You are enter quantity is",Obj.get_count().getsscount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getssprice(Obj),qty)
                    ans = input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         Obj.get_pbill().getpbill(Obj,qty)
#                         flag=False
                    
                elif(option==2):
                    print(Obj.getDishName().getKachori(Obj),"      ",Obj.getPrice().getkkprice(Obj),"Rs")
                    qty = int(input("Enter your quantity for Kachori:"))
                    print("You are enter quantity is",Obj.get_count().getkkcount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getkkprice(Obj),qty)
                    ans = input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                        
                        
            elif(option=="B"):
                Obj.getMenuPrint().Veg(Obj)
                option = int(input("Enter your Dish name:"))
                if(option==1):
                    print(Obj.getDishName().getPaneer(Obj),"      ",Obj.getPrice().getppprice(Obj),"Rs")
                    qty = int(input("Enter your quantity for Palak Paneer:"))
                    print("You are enter quantity is",Obj.get_count().getppcount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getppprice(Obj),qty)
                    ans=input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                         
                elif(option==2):
                    print(Obj.getDishName().getBhature(Obj),"     ",Obj.getPrice().getcbprice(Obj),"Rs")
                    qty=int(input("Enter your quantity for Chhole Bhature:"))
                    print("You are enter quantity is",Obj.get_count().getcbcount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getppprice(Obj),qty)
                    ans=input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                        
            elif(option=="C"):
                Obj.getMenuPrint().NonVeg(Obj)
                option = int(input("Enter your Dish name:"))
                if(option==1):
                    print(Obj.getDishName().getChilli(Obj),"     ",Obj.getPrice().getccprice(Obj),"Rs")
                    qty=int(input("Enter your quantity for Chilli Chicken:"))
                    print("You are enter quantity is",Obj.get_count().getcccount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getccprice(Obj),qty)
                    ans=input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                        
                    
                elif(option==2):
                    print(Obj.getDishName().getBiryani(Obj),"     ",Obj.getPrice().getbbprice(Obj),"Rs")
                    qty=int(input("Enter your quantity for Chicken Biryani:"))
                    print("You are enter quantity is",Obj.get_count().getbbcount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getppprice(Obj),qty)
                    ans=input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                        
            elif(option=="D"):
                Obj.getMenuPrint().Dessort(Obj)
                option = int(input("Enter your Dish name:"))
                if(option==1):
                    print(Obj.getDishName().getRmalai(Obj),"     ",Obj.getPrice().getrmprice(Obj),"Rs")
                    qty=int(input("Enter your quantity for Ras Malai:"))
                    print("You are enter quantity is",Obj.get_count().getrmcount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getrmprice(Obj),qty)
                    ans=input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                                            
                elif(option==2):
                    print(Obj.getDishName().getGjamun(Obj),"     ",Obj.getPrice().getgmprice(Obj),"Rs")
                    qty=int(input("Enter your quantity for Gulab Jamun:"))
                    print("You are enter quantity is",Obj.get_count().getgmcount(qty))
                    Obj.getBill().updateBill(Obj.getPrice().getgmprice(Obj),qty)
                    ans=input("Enter your second order:")
                    if(ans=="yes"):
                        print(Obj.getOrderAgain().orderAgain(Obj))
                    elif(ans=="no"):
                        v = Obj.getBill().getBill(Obj)
                        print("Your Final Bill Amount is",v,"Rs")
                        Obj.getdiscount().printdiscount(Obj,qty,v)
#                         flag=False
                        
            elif(option=="E"):
                print("                    --------THANK YOU FOR VISTING-------")
#                 flag=False
                
            else:
                print("Please, enter corrct option!")
                Obj.getMenu().printMenu(Obj)
    
class menuPrint:
    def Snacks(self,Obj):
        print("You are select Snacks.")
        print("1.Samosa")
        print("2.Kachori")
    def Veg(self,Obj):
        print("You are select Veg.")
        print("1.Palak Paneer")
        print("2.Chhole Bhature")
    def NonVeg(self,Obj):
        print("You are select Non Veg.")
        print("1.Chilli Chicken")
        print("2.Chicken Biryani")
    def Dessort(self,Obj):
        print("You are select Dessort.")
        print("1.Ras Malai")
        print("2.Gulab Jamun")
        

    
class dishName:
    ss = "Samosa"
    kk = "Kachori"
    pp = "Palak Paneer"
    cb = "Chhole Bhature"
    cc = "Chilli Chicken"
    bb = "Chicken Biryani"
    rm = "Ras Malai"
    gm = "Gulab Jamun"
    def getSamosa(self,Obj):
        return self.ss
    def getKachori(self,Obj):
        return self.kk
    def getPaneer(self,Obj):
        return self.pp
    def getBhature(self,Obj):
        return self.cb
    def getChilli(self,Obj):
        return self.cc
    def getBiryani(self,Obj):
        return self.bb
    def getRmalai(self,Obj):
        return self.rm
    def getGjamun(self,Obj):
        return self.gm
    
    
class price:
    ss = 35
    kk = 30
    pp = 300
    cb = 230
    cc = 400
    bb = 450
    rm = 40
    gm = 30
    def getssprice(self,Obj):
        return self.ss
    def getkkprice(self,Obj):
        return self.kk
    def getppprice(self,Obj):
        return self.pp
    def getcbprice(self,Obj):
        return self.cb
    def getccprice(self,Obj):
        return self.cc
    def getbbprice(self,Obj):
        return self.bb
    def getrmprice(self,Obj):
        return self.rm
    def getgmprice(self,Obj):
        return self.gm
    
class ccount:
    sscount = 0
    def getsscount(self,qty):
        self.sscount = self.sscount + qty
        return self.sscount
    def get_samosa_count(self):
        return self.sscount
    kkcount = 0
    def getkkcount(self,qty):
        self.kkcount = self.kkcount + qty
        return self.kkcount
    def get_kachori_count(self):
        return self.kkcount
    ppcount = 0
    def getppcount(self,qty):
        self.ppcount = self.ppcount + qty
        return self.ppcount
    def get_paneer_count(self):
        return self.ppcount
    cbcount = 0
    def getcbcount(self,qty):
        self.cbcount = self.cbcount + qty
        return self.cbcount
    def get_bhature_count(self):
        return self.cbcount
    cccount = 0
    def getcccount(self,qty):
        self.cccount = self.cccount + qty
        return self.cccount
    def get_chilli_count(self):
        return self.cccount
    bbcount = 0
    def getbbcount(self,qty):
        self.bbcount = self.bbcount + qty
        return self.bbcount
    def get_biryani_count(self):
        return self.bbcount
    rmcount = 0
    def getrmcount(self,qty):
        self.rmcount = self.rmcount + qty
        return self.rmcount
    def get_malai_count(self):
        return self.rmcount
    gmcount = 0
    def getgmcount(self,qty):
        self.gmcount = self.gmcount + qty
        return self.gmcount
    def get_gulab_count(self):
        return self.gmcount
    
class Again:
    def orderAgain(self,obj):
        Obj.getMenu().printMenu(Obj)
    
class Bill:
    bill=0
    def updateBill(self,qty,amt):
        self.bill = self.bill + amt*qty
        print("Your Current Bill Amount is",self.bill,"Rs")
    def getBill(self,Obj):
        return self.bill

class discount:
    def printdiscount(self,Obj,qty,v):
        day = input("Enter todays day:")
        if(day=="sunday"):
            discount = v*35/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        elif(day=="monday"):
            discount = v*20/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        elif(day=="tuesday"):
            discount = v*15/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        elif(day=="wednesday"):
            discount = v*12/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        elif(day=="thursday"):
            discount = v*15/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        elif(day=="friday"):
            discount = v*18/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        elif(day=="saturday"):
            discount = v*25/100
            Obj.get_pbill().getpbill(Obj,qty)
            fbill = v-discount
            print("Your discount is",discount)
            print("Your total bill amount is",fbill)
        
        
# class Pbill:
#     def getpbill(self,qty,Obj):
#         print("----------------------BILL-----------------------")
#         print("DishName    " ,"Dishprice     ","Quantity      "," Dishprice*Quantity    ")
#         if(Obj.get_count().get_samosa_count()!=0):
#             print(Obj.getDishName().getSamosa(Obj)," ",Obj.getPrice().getssprice(Obj)," ",Obj.getCount().getsscount(qty)," ",Obj.getPrice().getssprice(Obj)*Obj.getCount().getsscount(qty))
#         if(Obj.get_count().getkkcount(qty)!=0):
#             print(Obj.getDishName().getKachori(Obj)," ",Obj.getPrice().getkkprice(Obj)," ",Obj.getCount().getkkcount(qty)," ",Obj.getPrice().getkkprice(Obj)*Obj.getCount().getkkcount(qty))
#         if(Obj.get_Count().getppcount(qty)!=0):   
#             print(Obj.getDishName().getPaneer(Obj)," ",Obj.getPrice().getppprice(Obj)," ",Obj.getCount().getkkcount(qty)," ",Obj.getPrice().getppprice(Obj)*Obj.getCount().getppcount(qty))
# #         if(Obj.getCount().getcbcount(qty)):
# #             print(Obj.getDishName().getBhature(Obj)," ",)
    
    
class ObjFact:
    h = hotel()
    m = menu()
    mp = menuPrint()
    dn = dishName()
    p = price()
    c = ccount()
    a = Again()
    b = Bill()
    d = discount()
    e = Pbill()
    def gethotel(self):
        return self.h
    def getMenu(self):
        return self.m
    def getMenuPrint(self):
        return self.mp
    def getDishName(self):
        return self.dn
    def getPrice(self):
        return self.p
    def get_count(self):
        return self.c
    def getOrderAgain(self):
        return self.a
    def getBill(self):
        return self.b
    def getdiscount(self):
        return self.d
    def get_pbill(self):
        return self.e
    
Obj=ObjFact()
s=Obj.gethotel().welcome(Obj)
# Out:
#                          # WELCOME TO YASH KA DABHA #
#                        ---------------------------------
# Select your Option:-
# A.Snacks
# B.Veg
# C.Non-Veg
# D.Dessorts
# E.Exit
# Enter the your option A/B/C/D/E:-A
# You are select Snacks.
# 1.Samosa
# 2.Kachori
# Enter your Dish name:2
# Kachori        30 Rs

# %%
class taj_hotel:
    def get_welcome(self,obj):
        print(":::::::::::::::::welcome to taj hotel:::::::::::::::::")
        obj.get_menu().getmenu(obj)

class menu:
    def new_order(self,total,obj,qty):
        print("-- do you want to order anything else?--")
        select=input("(yes/no)")
        if(select =="no"):
            print("**your final bill is : ",total)
            day = input("enter today's day : ")
            if(day=="monday"):
                discount = total * 5/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            elif(day=="tuesday"):
                discount = total * 7/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            elif(day=="wednesday"):
                discount = total * 10/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            elif(day=="thusday"):
                discount = total * 12/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            elif(day=="friday"):
                discount = total * 15/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            elif(day=="saturday"):
                discount = total * 20/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            elif(day=="sunday"):
                discount = total * 25/100;
                obj.get_multi_bill().call_multibill(obj)
                print("your discount is :",discount)
                print("your final bill after discount is: ",total-discount)
            
            
            print("--------thank your for ordering-------- ")
            return False 
        else:
            print("******enter your new order****** ")
            return True
    def getmenu(self,obj):
        flag=True
        while flag:
            print("1 --> snacks")
            print("2 --> veg")
            print("3 --> non_veg")
            print("4 --> dessert")
            print("5 --> exit")
            option =int(input("enter your choice : "))
            if(option == 1):
                print("-------------SNACKS-------------")
                obj.get_menuprint().snacks()
                option = int(input("select your meal : "))
                print("--please enter your quantity--")
                if(option ==1):
                    print(obj.get_dishname().get_samosa(), "is selected ")
                    b = obj.get_bill()
                    print("the price of samosa is :",obj.get_price().price_samosa())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_samosa(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_samosa(qty))
                    total=obj.get_bill().print_bill()
                    print("your total bill  is : ", total)
                    flag =obj.get_menu().new_order(total,obj,qty)
    
                elif(option ==2):
                    print(obj.get_dishname().get_kachodi(), "is selected ")
                    b = obj.get_bill()
                    print("the price of kachodi is :",obj.get_price().price_kachodi())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_kachodi(),qty)
                    print("your total count of kachodi is : ", obj.get_count().count_kachodi(qty))
                    
                    total=obj.get_bill().print_bill()
                    print("your total bill  is : ", total)
                    flag =obj.get_menu().new_order(total,obj,qty)
                    
            elif(option == 2):
                print("-------------VEG MEAL-------------")
                
                obj.get_menuprint().veg()
                option = int(input("select your meal : "))
                print("--please enter your quantity--")
                if(option ==1):
                    print(obj.get_dishname().get_raita(), "is selected ")
                    b = obj.get_bill()
                    print("the price of raita is :",obj.get_price().price_raita())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_raita(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_raita(qty))
                    
                    total=obj.get_bill().print_bill()
                    
                    print("your total bill  is : ", total)
                    flag =obj.get_menu().new_order(total,obj,qty)

    
                elif(option ==2):
                    print(obj.get_dishname().get_pulav(), "is selected ")
                    b = obj.get_bill()
                    print("the price of pulav is :",obj.get_price().price_pulav())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_pulav(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_pulav(qty))
                    
                    total=obj.get_bill().print_bill()

                    print("your total bill  is : ", total)

                    flag =obj.get_menu().new_order(total,obj,qty)

                    
            elif(option == 3):
                print("-------------NON-VEG MEAL-------------")
                
                obj.get_menuprint().non_veg()
                option = int(input("select your meal : "))
                print("--please enter your quantity--")
                if(option ==1):
                    print(obj.get_dishname().get_mutton(), "is selected ")
                    b = obj.get_bill()
                    print("the price of mutton biryani is :",obj.get_price().price_mutton())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_mutton(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_mutton(qty))
                    
                    total=obj.get_bill().print_bill()

                    print("your total bill  is : ", total)

                    flag =obj.get_menu().new_order(total,obj,qty)
                    
    
                elif(option ==2):
                    print(obj.get_dishname().get_butter(), "is selected ")
                    b = obj.get_bill()
                    print("the price of butter chicken is :",obj.get_price().price_butter())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_butter(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_butter(qty))
                    
                    total=obj.get_bill().print_bill()
                                        
                    print("your total bill  is : ", total)

                    flag =obj.get_menu().new_order(total,obj,qty)
                    
            elif(option == 4):
                print("-------------DESSERT-------------")
                
                obj.get_menuprint().dessert()
                option = int(input("select your meal : "))
                print("--please enter your quantity--")
                if(option ==1):
                    print(obj.get_dishname().get_ice(), "is selected ")
                    b = obj.get_bill()
                    print("the price of mutton biryani is :",obj.get_price().price_ice())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_ice(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_ice(qty))
                    
                    total=obj.get_bill().print_bill()

                    print("your total bill  is : ", total)

                    flag =obj.get_menu().new_order(total,obj,qty)
    
                elif(option ==2):
                    print(obj.get_dishname().get_gulab(), "is selected ")
                    b = obj.get_bill()
                    print("the price of butter chicken is :",obj.get_price().price_gulab())
                    qty = int(input("enter your quantity "))
                    b.updatebill(obj.get_price().price_gulab(),qty)
                    print("your total count of samosa is : ", obj.get_count().count_gulab(qty))
                    
                    total=obj.get_bill().print_bill()

                    print("your total bill  is : ", total)

                    flag =obj.get_menu().new_order(total,obj,qty)
            elif(option ==5):
                print("---------thank you ---------")
                flag = False
            else:
                print("please enter a correct option")
                    
class multi_bill:
    def call_multibill(self,obj):
        print("dishname ,   price    ,quantity     , totalbill  ")
        if( obj.get_count().get_samosa_count()>0):
            print(obj.get_dishname().get_samosa(),obj.get_price().price_samosa(),obj.get_count().get_samosa_count(),"=",obj.get_price().price_samosa()*obj.get_count().get_samosa_count())
        if(obj.get_count().get_kachodi_count()>0):   
            print(obj.get_dishname().get_kachodi(),obj.get_price().price_kachodi(),obj.get_count().get_kachodi_count(),"=",obj.get_price().price_kachodi()*obj.get_count().get_kachodi_count())
        if(obj.get_count().get_raita_count()>0):
            print(obj.get_dishname().get_raita(),obj.get_price().price_raita(),obj.get_count().get_raita_count(),"=",obj.get_price().price_raita()*obj.get_count().get_raita_count())
        if(obj.get_count().get_pulav_count()>0):
            print(obj.get_dishname().get_pulav(),obj.get_price().price_pulav(),obj.get_count().get_pulav_count(),"=",obj.get_price().price_pulav()*obj.get_count().get_pulav_count())
        if(obj.get_count().get_mutton_count()>0):
            print(obj.get_dishname().get_mutton(),obj.get_price().price_mutton(),obj.get_count().get_mutton_count(),"=",obj.get_price().price_mutton()*obj.get_count().get_mutton_count()) 
        if(obj.get_count().get_butter_count()>0):
            print(obj.get_dishname().get_butter(),obj.get_price().price_butter(),obj.get_count().get_butter_count(),"=",obj.get_price().price_butter()*obj.get_count().get_butter_count())
        if(obj.get_count().get_mutton_count()>0):
            print(obj.get_dishname().get_mutton(),obj.get_price().price_mutton(),obj.get_count().get_mutton_count(),"=",obj.get_price().price_mutton()*obj.get_count().get_mutton_count())
        if(obj.get_count().get_ice_count()>0):
            print(obj.get_dishname().get_ice(),obj.get_price().price_ice(),obj.get_count().get_ice_count(),"=",obj.get_price().price_ice()*obj.get_count().get_ice_count())
        if(obj.get_count().get_gulab_count()>0):
            print(obj.get_dishname().get_gulab(),obj.get_price().price_gulab(),obj.get_count().get_gulab_count(),"=",obj.get_price().price_gulab()*obj.get_count().get_gulab_count())
class menu_print:
    def snacks(self):
        print("1 for samosa")
        print("2 for kachodi")
    def veg(self):
        print("1 for raita")
        print("2 for pulav")
    def non_veg(self):
        print("1 for mutton biryani")
        print("2 for butter chicken")
        
    def dessert(self):
        print("1 for ice cream")
        print("2 for gulab jamun")
        
class dishname:
    ss = "samosa"
    kk = "kachodi"
    r="raita"
    pu="pulav"
    mb = "mutton biryani"
    bc="butter chicken"
    ic="ice cream"
    gj="gulab jamun"
    def get_samosa(self):
        return self.ss
    def get_kachodi(self):
        return self.kk
    def get_raita(self):
        return self.r
    def get_pulav(self):
        return self.pu
    def get_mutton(self):
        return self.mb
    def get_butter(self):
        return self.bc
    def get_ice(self):
        return self.ic
    def get_gulab(self):
        return self.gj
    
class price:
    ss = 25
    kk = 20
    r=40
    pu=50
    mb =100
    bc=70
    ic=10
    gj=25
    def price_samosa(self):
        return self.ss
    def price_kachodi(self):
        return self.kk
    def price_raita(self):
        return self.r
    def price_pulav(self):
        return self.pu
    def price_mutton(self):
        return self.mb
    def price_butter(self):
        return self.bc
    def price_ice(self):
        return self.ic
    def price_gulab(self):
        return self.gj

class bill:
    bill =0
    def updatebill(self,amt,qty):
        self.bill =self.bill + amt*qty
        print("your current bill is :",self.bill)
    def print_bill(self):
        return self.bill
    
class count:
    ss_count = 0
    kk_count = 0
    r_count=0
    pu_count=0
    mb_count =0
    bc_count=0
    ic_count=0
    gj_count=0
    def count_samosa(self,qty):
        self.ss_count=self.ss_count + qty
        return self.ss_count
    def get_samosa_count(self):
        return self.ss_count
    
    def count_kachodi(self,qty):
        self.kk_count=self.kk_count + qty
        return self.kk_count
    def get_kachodi_count(self):
        return self.kk_count
      
    def count_raita(self,qty):
        self.r_count=self.r_count  + qty
        return self.r_count
    def get_raita_count(self):
        return self.r_count
            
    def count_pulav(self,qty):
        self.pu_count=self.pu_count + qty
        return self.pu_count
    def get_pulav_count(self):
        return self.pu_count
            
    def count_mutton(self,qty):
        self.mb_count=self.mb_count + qty
        return self.mb_count
    def get_mutton_count(self):
        return self.mb_count
            
    def count_butter(self,qty):
        self.bc_count=self.bc_count + qty
        return self.bc_count
    def get_butter_count(self):
        return self.bc_count
            
    def count_ice(self,qty):
        self.ic_count=self.ic_count + qty
        return self.ic_count
    def get_ice_count(self):
        return self.ic_count
            
    def count_gulab(self,qty):
        self.gj_count=self.gj_count + qty
        return self.gj_count
    def get_gulab_count(self):
        return self.gj_count

class object_factory:
    t=taj_hotel()
    m = menu()
    mp = menu_print()
    dn=dishname()
    p = price()
    b = bill()
    c = count()
    mb=multi_bill()
#     oa=order_again()
#     def again_order(self):
#         return self.oa
    def get_multi_bill(self):
        return self.mb
    def get_hotel(self):
        return self.t
    def get_menu(self):
        return self.m
    def get_menuprint(self):
        return self.mp
    def get_dishname(self):
        return self.dn
    def get_price(self):
        return self.p
    def get_bill(self):
        return self.b
    def get_count(self):
        return self.c
obj = object_factory()
obj.get_hotel().get_welcome(obj)
# Out:
# :::::::::::::::::welcome to taj hotel:::::::::::::::::
# 1 --> snacks
# 2 --> veg
# 3 --> non_veg
# 4 --> dessert
# 5 --> exit
# enter your choice : 1
# -------------SNACKS-------------
# 1 for samosa
# 2 for kachodi
# select your meal : 1
# --please enter your quantity--
# samosa is selected
# the price of samosa is : 25
# enter your quantity 3
# your current bill is : 75
# your total count of samosa is :  3
# your total bill  is :  75
# -- do you want to order anything else?--
# (yes/no)yes
# ******enter your new order******
# 1 --> snacks
# 2 --> veg
# 3 --> non_veg
# 4 --> dessert
# 5 --> exit
# enter your choice : 1
# -------------SNACKS-------------
# 1 for samosa
# 2 for kachodi
# select your meal : 1
# --please enter your quantity--
# samosa is selected
# the price of samosa is : 25
# enter your quantity 6
# your current bill is : 225
# your total count of samosa is :  9
# your total bill  is :  225
# -- do you want to order anything else?--
# (yes/no)yes
# ...
